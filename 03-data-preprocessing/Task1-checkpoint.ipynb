# %% [markdown]
# ## The Exercise
#
# Your goal is to create a document that wrestles with the following question:
#
# **Is this dataset a good candidate for training a neural network based regression model to predict housing prices?**
#
# The dataset is the same dataset linked and discussed in 02-preprocessing-structured-data.ipynb, and can be downloaded here: [https://www.kaggle.com/new-york-city/nyc-property-sales](https://www.kaggle.com/new-york-city/nyc-property-sales)
#
# Your report should have 3 sections.
#
# In the first section, you should write 2-3 paragraphs about the potential sources of bias and errors that could impact this dataset. You should consider issues such as where the data came from, who compiled it, what societal or institutional biases could be at play, how the data might be misinterpreted by a machine learning model. These paragraphs you should be as descriptive as possible about the risks (or lack thereof) of using this data. In other words, if we train a regression model using this data, will it tell us what we think it should tell us (e.g. accurately predict the price of similar houses into the future) or are the sources of bias and error likely to result in our models failure to achieve its goals.
#
# In the second section, you should perform data cleanup and numerical analysis. Here, you should assume the data is relatively bias-free, and determine if it is still a good fit for a neural network using statistical arguments. Questions to ask here: does the data have strong signal, do the fields in our data correlate with the labels (price)? Is there a lot of missing, or misleading data in the data set? Are there too many outliers? Furthermore, you should argue in favor of keeping or removing certain pieces of data. Are all the columns actually useful, or should some be removed? Is it appropriate to remove some outliers? If we do, will we still have enough data to train our model?
#
# Finally, in the third section, write 1 or 2 paragraphs describing your conclusion: is this dataset good enough to train a neural network based regression model* to predict housing prices in NYC.
#
# *Regression Model:   Regression model means an investment analysis tool used by investors to compare two or more stock variables.
#
# Regardless of what you conclude in your report—you may enjoy testing your hypothesis by attempting to build a neural network based regression model using this as training data. Good luck!

# %% [markdown]
# In the first section, you should write 2-3 paragraphs about the
# potential sources of bias and
# errors that could impact this dataset.
#
# You should consider issues such as
# where the data came from,
# who compiled it,
# what societal or institutional biases could be at play,
#
# how the data might be misinterpreted by a machine learning model.
#
# These paragraphs you should be as descriptive as possible about the risks (or lack thereof) of using this data.
#
# In other words, if we train a regression model using this data, will it tell us what we think it should tell us (e.g. accurately predict the price of similar houses into the future) or are the sources of bias and error likely to result in our models failure to achieve its goals.
#
# ---
#
#
# So right off the bat; this is NYC so the Machine is going to be accurate toward NYC Price ranges
# - But if it was given Georgia properies; we may see inaccuracy due to the difference in Property Values
# - I think the most value I could Promise to someone is that we can determine the average cost of property
# based on the address
# - The other value would be the peak sales times (when are times people are most likely to sale)
# - Not all addresses will have all of the data; there are quite a few addresses with pockets and no assignments to them.
# How would the model interpret these 0s? Will it just assume that the cost of it is NO sale? This leave unsatisfactory answers to certain properties.
#
# -

# %% [markdown]
# In the second section, you should perform data cleanup and numerical analysis.
#
# Here, you should assume the data is relatively bias-free, and determine if it is still a good fit for a neural network using statistical arguments.
#
# Questions to ask here: does the data have strong signal, * ?? Def Unclea
# - do the fields in our data correlate with the labels (price)?
# Yes; all values have a value related to it once all of the 0s were removed in the
# previous lessons.
#
# - Is there a lot of missing, or misleading data in the data set?
# APT Num is missing; I don't this is an issue
# Res Units: Comm Units: Total Units are sometimes all 0s - unsure what this mean in data
# Land SQ: Gross SQ -> Sometimes this data is 0; this seems to be false
#
# - Are there too many outliers?
# 245 Park Avenue is an extremely highly priced value (if you see below) totalling at
# 2.0billion
#
# Using Power BI I can see that mot sales total to around 200K
# ![image.png](attachment:image.png)
#
#
# *Strong Signal:
#
# Furthermore, you should argue in favor of keeping or removing certain pieces of data.
# - Are all the columns actually useful, or should some be removed?
# APT Num Can be removed
# EASE0MENT doesn't have any value and can be removed
#
#
# - Is it appropriate to remove some outliers?
# I don't think its important to remove Park Avenue as a severely high priced property
# Park Avenue I imagine would be worth alot of money
#
# If we do, will we still have enough data to train our model?
# - If we removed Park Avenue we would have plenty of data to train the model for sure.
#
#
# ---

# %% [markdown]
# Finally, in the third section, write 1 or 2 paragraphs describing your conclusion: is this dataset good enough to train a neural network based regression model* to predict housing prices in NYC.
#
# The data would be good enough to train a model;
# but there is quite a bit of unknown in regards to the customers' expectation.
#
# I think it would be useful to prvide correlational data with Residential and Commercial data
# but the customer may not think so.
#
# Zip Code data may be useful to correlate cost per Zip Code; but this does not mean that the customer would
# care about this.
#
# Ultimately I think with the trimmed up data as is; would be useful for Property values in New York.
# Also removing the Sale Price data of 0 would be useful as well since I don't know what this means.
# other than it hasn't sold anything, if we kept the 0s then that would cause the AI to predict 0 for some prices
# - Which may not be valuable.
