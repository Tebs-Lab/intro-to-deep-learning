# %% [markdown]
# # CNNs and DQNs: Playing From Pixels
#
# Instead of relying on some kind of state transformer—that is some way to get relevant state information from the game itself—we can use CNN's and use a short sequence of screen captures of the pixels on the screen as the state. Doing so models the way humans play games (we don't know the internal state values) and is a much more general approach (every video game involves frames of pixels).
#
# ![](images/CNN-DQN.jpg)
#
# > Image Source: https://storage.googleapis.com/deepmind-media/dqn/DQNNaturePaper.pdf

# %%
import numpy as np

import io
import base64
from IPython import display

import gym
from gym import wrappers

# Same as before, just allowing us to display the video from OpenAI Gym 
def imbed_round_video(video_env):
    video = io.open('./gym-videos/openaigym.video.%s.video000001.mp4' % video_env.file_infix, 'r+b').read()
    encoded = base64.b64encode(video)
    return display.HTML(data='''
        <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,{0}" type="video/mp4" /></video>'''
    .format(encoded.decode('ascii')))

# %%
# Much of the code here is borrowed directly from the 
# keras-rl package examples, which you can find here: 
#    https://github.com/keras-rl/keras-rl/tree/master/examples

from PIL import Image
import numpy as np
import gym

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Convolution2D, Permute
from keras.optimizers import Adam
import keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

INPUT_SHAPE = (84, 84)

# The window length enables us to capture more information in a "state"
# than the current pixels on the screen. Consider this: if each state was
# a single snapshot, how would our AI ever know the velocity of the ball?
# A window length of 4 means a "state" is actually the combination of 4
# frames of the game. 
WINDOW_LENGTH = 4

# keras-rl provides this processor which allows us to use the pixel's from 
# the OpenAI Gym Atari selection and process those pixels into an image that
# play's well with Keras' expectations for CNN inputs. 

# For efficency reasons they suggest transforming the images to grayscale 
# before sending them to a CNN. 
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)

        # NOTE THAT: each frame from the atari game is squashed to INPUT_SHAPE
        # and then converted to grayscale. 
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')  # resize and convert to grayscale
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')  # saves storage in experience memory

    def process_state_batch(self, batch):
        # We could perform this processing step in `process_observation`. In this case, however,
        # we would need to store a `float32` array instead, which is 4x more memory intensive than
        # an `uint8` array. This matters if we store 1M observations.
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

#     # TODO: See if we need this... seems kind of wrong headed to me actually. 
#     def process_reward(self, reward):
#         return np.clip(reward, -1., 1.)
# Out:
# Using TensorFlow backend.

# %%
# This could would work for just about any of the pixel 
# returning OpenAI environments. Feel free to try many games. 
env = gym.make("Breakout-v0")
nb_actions = env.action_space.n

# We'll use a relatively simple model that starts with fairly big
# strides to compress the input size quickly. This idea is described
# in Minh et al. (2015): https://www.nature.com/articles/nature14236

# Remember window length is the number of frames, and INPUT_SHAPE is
# the shape of each grayscale frame. 
input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE
model = Sequential()

# Some backeneds have the color channel first, some have it last.
# This code accounts for that. 
if K.image_dim_ordering() == 'tf':
    # (width, height, channels)
    model.add(Permute((2, 3, 1), input_shape=input_shape))
elif K.image_dim_ordering() == 'th':
    # (channels, width, height)
    model.add(Permute((1, 2, 3), input_shape=input_shape))

# Note the significant striding.
model.add(Convolution2D(32, (8, 8), strides=(4, 4), activation='relu'))
model.add(Convolution2D(64, (4, 4), strides=(2, 2), activation='relu'))
model.add(Convolution2D(64, (3, 3), strides=(1, 1), activation='relu'))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(nb_actions, activation='linear'))

memory = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)
processor = AtariProcessor()

# Direct from the keras-rl docs/example: 

# Select a policy. We use eps-greedy action selection, which means that a random action is selected
# with probability eps. We anneal eps from 1.0 to 0.1 over the course of 1M steps. This is done so that
# the agent initially explores the environment (high eps) and then gradually sticks to what it knows
# (low eps). We also set a dedicated eps value that is used during testing. Note that we set it to 0.05
# so that the agent still performs some random actions. This ensures that the agent cannot get stuck.

policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), 
              attr='eps', value_max=.99, value_min=.05, value_test=.05, nb_steps=1250000
         )
# policy = EpsGreedyQPolicy() 

# Note the "train interval" matches our WINDOW_LENGTH, not by accident. 
dqn = DQNAgent(model=model, nb_actions=nb_actions, policy=policy, memory=memory,
               processor=processor, nb_steps_warmup=10000, gamma=.99, target_model_update=0.01,
               train_interval=4, delta_clip=1.)

# Note the low learning rate. 
dqn.compile(Adam(lr=.00025), metrics=['mae'])
# Out:
# WARNING:tensorflow:From /Users/tylerbettilyon/.local/share/virtualenvs/deep-learning-intro-1Adgpw9A/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# Notice that we just went for a huge number of steps right off the bat. 
# Feel free to divide these steps into smaller steps to visualize performance
# over time. 
dqn.fit(env, nb_steps=1750000, nb_max_start_steps=30, verbose=True, action_repetition=2)

# Note the warm up period the network seems really fast! ~20s per 10k steps. 
# then the actual RL kicks in at interval 6 and we see closer to 3-5 minutes per 10k steps.
# Out:
# Training for 1750000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 29s 3ms/step - reward: 0.0118
# 78 episodes - episode_reward: 1.487 [0.000, 8.000] - ale.lives: 5.698
#
# Interval 2 (10000 steps performed)
#     1/10000 [..............................] - ETA: 1:26 - reward: 0.0000e+00WARNING:tensorflow:From /Users/tylerbettilyon/.local/share/virtualenvs/deep-learning-intro-1Adgpw9A/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 10000/10000 [==============================] - 251s 25ms/step - reward: 0.0101
# 83 episodes - episode_reward: 1.217 [0.000, 4.000] - loss: 0.006 - mean_absolute_error: 0.098 - mean_q: 0.133 - mean_eps: 0.979 - ale.lives: 5.695
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 255s 25ms/step - reward: 0.0124
# 78 episodes - episode_reward: 1.577 [0.000, 6.000] - loss: 0.010 - mean_absolute_error: 0.346 - mean_q: 0.464 - mean_eps: 0.971 - ale.lives: 5.754
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 251s 25ms/step - reward: 0.0120
# 81 episodes - episode_reward: 1.519 [0.000, 5.000] - loss: 0.017 - mean_absolute_error: 0.887 - mean_q: 1.200 - mean_eps: 0.964 - ale.lives: 5.778
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 252s 25ms/step - reward: 0.0124
# 77 episodes - episode_reward: 1.597 [0.000, 4.000] - loss: 0.014 - mean_absolute_error: 1.539 - mean_q: 2.081 - mean_eps: 0.956 - ale.lives: 5.563
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 249s 25ms/step - reward: 0.0134
# 75 episodes - episode_reward: 1.773 [0.000, 5.000] - loss: 0.013 - mean_absolute_error: 1.986 - mean_q: 2.681 - mean_eps: 0.949 - ale.lives: 5.712
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 254s 25ms/step - reward: 0.0139
# 76 episodes - episode_reward: 1.842 [0.000, 8.000] - loss: 0.013 - mean_absolute_error: 2.257 - mean_q: 3.041 - mean_eps: 0.941 - ale.lives: 5.688
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 255s 25ms/step - reward: 0.0138
# 75 episodes - episode_reward: 1.827 [0.000, 7.000] - loss: 0.016 - mean_absolute_error: 2.474 - mean_q: 3.331 - mean_eps: 0.934 - ale.lives: 5.721
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 254s 25ms/step - reward: 0.0139
# 74 episodes - episode_reward: 1.878 [0.000, 6.000] - loss: 0.019 - mean_absolute_error: 2.716 - mean_q: 3.655 - mean_eps: 0.926 - ale.lives: 5.427
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 253s 25ms/step - reward: 0.0140
# 75 episodes - episode_reward: 1.893 [0.000, 5.000] - loss: 0.022 - mean_absolute_error: 2.927 - mean_q: 3.936 - mean_eps: 0.919 - ale.lives: 5.641
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 244s 24ms/step - reward: 0.0131
# 76 episodes - episode_reward: 1.697 [0.000, 6.000] - loss: 0.025 - mean_absolute_error: 3.089 - mean_q: 4.144 - mean_eps: 0.911 - ale.lives: 5.641
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 255s 26ms/step - reward: 0.0148
# 72 episodes - episode_reward: 2.083 [0.000, 7.000] - loss: 0.025 - mean_absolute_error: 3.148 - mean_q: 4.223 - mean_eps: 0.904 - ale.lives: 5.708
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 262s 26ms/step - reward: 0.0145
# 71 episodes - episode_reward: 2.028 [0.000, 5.000] - loss: 0.027 - mean_absolute_error: 3.270 - mean_q: 4.388 - mean_eps: 0.896 - ale.lives: 5.618
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 251s 25ms/step - reward: 0.0142
# 73 episodes - episode_reward: 1.932 [0.000, 6.000] - loss: 0.030 - mean_absolute_error: 3.330 - mean_q: 4.465 - mean_eps: 0.888 - ale.lives: 5.525
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 266s 27ms/step - reward: 0.0142
# 72 episodes - episode_reward: 1.931 [0.000, 5.000] - loss: 0.032 - mean_absolute_error: 3.393 - mean_q: 4.547 - mean_eps: 0.881 - ale.lives: 5.709
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 264s 26ms/step - reward: 0.0140
# 73 episodes - episode_reward: 1.986 [0.000, 5.000] - loss: 0.031 - mean_absolute_error: 3.411 - mean_q: 4.567 - mean_eps: 0.873 - ale.lives: 5.628
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 259s 26ms/step - reward: 0.0147
# 70 episodes - episode_reward: 2.086 [0.000, 10.000] - loss: 0.031 - mean_absolute_error: 3.415 - mean_q: 4.576 - mean_eps: 0.866 - ale.lives: 5.625
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 254s 25ms/step - reward: 0.0144
# 72 episodes - episode_reward: 1.986 [0.000, 6.000] - loss: 0.031 - mean_absolute_error: 3.393 - mean_q: 4.545 - mean_eps: 0.858 - ale.lives: 5.763
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 261s 26ms/step - reward: 0.0134
# 73 episodes - episode_reward: 1.836 [0.000, 6.000] - loss: 0.029 - mean_absolute_error: 3.340 - mean_q: 4.477 - mean_eps: 0.851 - ale.lives: 5.701
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 265s 27ms/step - reward: 0.0129
# 74 episodes - episode_reward: 1.770 [0.000, 6.000] - loss: 0.032 - mean_absolute_error: 3.352 - mean_q: 4.491 - mean_eps: 0.843 - ale.lives: 5.754
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 263s 26ms/step - reward: 0.0142
# 72 episodes - episode_reward: 1.958 [0.000, 5.000] - loss: 0.028 - mean_absolute_error: 3.262 - mean_q: 4.372 - mean_eps: 0.836 - ale.lives: 5.511
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 261s 26ms/step - reward: 0.0136
# 74 episodes - episode_reward: 1.824 [0.000, 5.000] - loss: 0.026 - mean_absolute_error: 3.181 - mean_q: 4.270 - mean_eps: 0.828 - ale.lives: 5.557
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 264s 26ms/step - reward: 0.0142
# 73 episodes - episode_reward: 1.959 [0.000, 7.000] - loss: 0.023 - mean_absolute_error: 3.112 - mean_q: 4.178 - mean_eps: 0.821 - ale.lives: 5.596
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 264s 26ms/step - reward: 0.0140
# 73 episodes - episode_reward: 1.918 [0.000, 6.000] - loss: 0.026 - mean_absolute_error: 3.058 - mean_q: 4.105 - mean_eps: 0.813 - ale.lives: 5.560
#
# Interval 25 (240000 steps performed)
# 10000/10000 [==============================] - 262s 26ms/step - reward: 0.0153
# 68 episodes - episode_reward: 2.235 [0.000, 7.000] - loss: 0.025 - mean_absolute_error: 3.041 - mean_q: 4.081 - mean_eps: 0.806 - ale.lives: 5.562
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 262s 26ms/step - reward: 0.0160
# 65 episodes - episode_reward: 2.462 [0.000, 7.000] - loss: 0.023 - mean_absolute_error: 3.000 - mean_q: 4.025 - mean_eps: 0.798 - ale.lives: 5.704
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 258s 26ms/step - reward: 0.0154
# 67 episodes - episode_reward: 2.313 [0.000, 7.000] - loss: 0.027 - mean_absolute_error: 3.049 - mean_q: 4.092 - mean_eps: 0.791 - ale.lives: 5.876
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 258s 26ms/step - reward: 0.0138
# 73 episodes - episode_reward: 1.890 [0.000, 7.000] - loss: 0.028 - mean_absolute_error: 3.126 - mean_q: 4.194 - mean_eps: 0.783 - ale.lives: 5.748
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 258s 26ms/step - reward: 0.0154
# 66 episodes - episode_reward: 2.348 [0.000, 8.000] - loss: 0.027 - mean_absolute_error: 3.145 - mean_q: 4.215 - mean_eps: 0.776 - ale.lives: 5.722
#
# Interval 30 (290000 steps performed)
# 10000/10000 [==============================] - 261s 26ms/step - reward: 0.0165
# 65 episodes - episode_reward: 2.538 [0.000, 6.000] - loss: 0.023 - mean_absolute_error: 3.046 - mean_q: 4.087 - mean_eps: 0.768 - ale.lives: 5.673
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 264s 26ms/step - reward: 0.0167
# 65 episodes - episode_reward: 2.538 [0.000, 8.000] - loss: 0.023 - mean_absolute_error: 3.012 - mean_q: 4.043 - mean_eps: 0.761 - ale.lives: 5.561
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 259s 26ms/step - reward: 0.0162
# 67 episodes - episode_reward: 2.388 [0.000, 10.000] - loss: 0.023 - mean_absolute_error: 2.941 - mean_q: 3.945 - mean_eps: 0.753 - ale.lives: 5.672
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 262s 26ms/step - reward: 0.0163
# 63 episodes - episode_reward: 2.651 [0.000, 7.000] - loss: 0.021 - mean_absolute_error: 2.885 - mean_q: 3.872 - mean_eps: 0.746 - ale.lives: 5.555
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 262s 26ms/step - reward: 0.0163
# 62 episodes - episode_reward: 2.629 [0.000, 8.000] - loss: 0.023 - mean_absolute_error: 2.902 - mean_q: 3.897 - mean_eps: 0.738 - ale.lives: 5.503
#
# Interval 35 (340000 steps performed)
# 10000/10000 [==============================] - 262s 26ms/step - reward: 0.0146
# 69 episodes - episode_reward: 2.101 [0.000, 8.000] - loss: 0.024 - mean_absolute_error: 2.893 - mean_q: 3.884 - mean_eps: 0.731 - ale.lives: 5.389
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 262s 26ms/step - reward: 0.0127
# 73 episodes - episode_reward: 1.753 [0.000, 7.000] - loss: 0.023 - mean_absolute_error: 2.889 - mean_q: 3.877 - mean_eps: 0.723 - ale.lives: 5.214
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 262s 26ms/step - reward: 0.0129
# 73 episodes - episode_reward: 1.767 [0.000, 9.000] - loss: 0.022 - mean_absolute_error: 2.868 - mean_q: 3.853 - mean_eps: 0.716 - ale.lives: 5.300
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 249s 25ms/step - reward: 0.0149
# 69 episodes - episode_reward: 2.159 [0.000, 9.000] - loss: 0.020 - mean_absolute_error: 2.800 - mean_q: 3.759 - mean_eps: 0.708 - ale.lives: 5.313
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 256s 26ms/step - reward: 0.0135
# 73 episodes - episode_reward: 1.836 [0.000, 7.000] - loss: 0.019 - mean_absolute_error: 2.631 - mean_q: 3.531 - mean_eps: 0.700 - ale.lives: 5.418
#
# Interval 40 (390000 steps performed)
# 10000/10000 [==============================] - 255s 25ms/step - reward: 0.0173
# 65 episodes - episode_reward: 2.677 [0.000, 9.000] - loss: 0.019 - mean_absolute_error: 2.529 - mean_q: 3.396 - mean_eps: 0.693 - ale.lives: 5.481
#
# Interval 41 (400000 steps performed)
# 10000/10000 [==============================] - 261s 26ms/step - reward: 0.0181
# 60 episodes - episode_reward: 2.983 [0.000, 10.000] - loss: 0.020 - mean_absolute_error: 2.533 - mean_q: 3.401 - mean_eps: 0.685 - ale.lives: 5.544
#
# Interval 42 (410000 steps performed)
# 10000/10000 [==============================] - 263s 26ms/step - reward: 0.0160
# 66 episodes - episode_reward: 2.439 [0.000, 10.000] - loss: 0.019 - mean_absolute_error: 2.530 - mean_q: 3.397 - mean_eps: 0.678 - ale.lives: 5.484
#
# Interval 43 (420000 steps performed)
# 10000/10000 [==============================] - 264s 26ms/step - reward: 0.0159
# 68 episodes - episode_reward: 2.353 [0.000, 9.000] - loss: 0.019 - mean_absolute_error: 2.539 - mean_q: 3.412 - mean_eps: 0.670 - ale.lives: 5.409
#
# Interval 44 (430000 steps performed)
# 10000/10000 [==============================] - 262s 26ms/step - reward: 0.0185
# 59 episodes - episode_reward: 3.102 [0.000, 10.000] - loss: 0.018 - mean_absolute_error: 2.513 - mean_q: 3.376 - mean_eps: 0.663 - ale.lives: 5.516
#
# Interval 45 (440000 steps performed)
# 10000/10000 [==============================] - 266s 27ms/step - reward: 0.0195
# 55 episodes - episode_reward: 3.527 [0.000, 9.000] - loss: 0.019 - mean_absolute_error: 2.535 - mean_q: 3.406 - mean_eps: 0.655 - ale.lives: 5.831
#
# Interval 46 (450000 steps performed)
# 10000/10000 [==============================] - 266s 27ms/step - reward: 0.0198
# 56 episodes - episode_reward: 3.536 [0.000, 11.000] - loss: 0.019 - mean_absolute_error: 2.593 - mean_q: 3.485 - mean_eps: 0.648 - ale.lives: 5.542
#
# Interval 47 (460000 steps performed)
# 10000/10000 [==============================] - 269s 27ms/step - reward: 0.0221
# 52 episodes - episode_reward: 4.269 [0.000, 10.000] - loss: 0.020 - mean_absolute_error: 2.648 - mean_q: 3.560 - mean_eps: 0.640 - ale.lives: 6.004
#
# Interval 48 (470000 steps performed)
# 10000/10000 [==============================] - 267s 27ms/step - reward: 0.0207
# 55 episodes - episode_reward: 3.764 [0.000, 11.000] - loss: 0.021 - mean_absolute_error: 2.713 - mean_q: 3.645 - mean_eps: 0.633 - ale.lives: 5.483
#
# Interval 49 (480000 steps performed)
# 10000/10000 [==============================] - 267s 27ms/step - reward: 0.0196
# 57 episodes - episode_reward: 3.474 [0.000, 9.000] - loss: 0.022 - mean_absolute_error: 2.766 - mean_q: 3.712 - mean_eps: 0.625 - ale.lives: 5.743
#
# Interval 50 (490000 steps performed)
# 10000/10000 [==============================] - 268s 27ms/step - reward: 0.0198
# 55 episodes - episode_reward: 3.564 [0.000, 9.000] - loss: 0.019 - mean_absolute_error: 2.754 - mean_q: 3.697 - mean_eps: 0.618 - ale.lives: 5.536
#
# Interval 51 (500000 steps performed)
# 10000/10000 [==============================] - 270s 27ms/step - reward: 0.0189
# 56 episodes - episode_reward: 3.321 [0.000, 12.000] - loss: 0.018 - mean_absolute_error: 2.697 - mean_q: 3.620 - mean_eps: 0.610 - ale.lives: 5.428
#
# Interval 52 (510000 steps performed)
# 10000/10000 [==============================] - 268s 27ms/step - reward: 0.0231
# 50 episodes - episode_reward: 4.620 [1.000, 9.000] - loss: 0.016 - mean_absolute_error: 2.576 - mean_q: 3.456 - mean_eps: 0.603 - ale.lives: 5.672
#
# Interval 53 (520000 steps performed)
# 10000/10000 [==============================] - 270s 27ms/step - reward: 0.0238
# 49 episodes - episode_reward: 4.939 [1.000, 11.000] - loss: 0.015 - mean_absolute_error: 2.521 - mean_q: 3.386 - mean_eps: 0.595 - ale.lives: 5.632
#
# Interval 54 (530000 steps performed)
# 10000/10000 [==============================] - 269s 27ms/step - reward: 0.0232
# 53 episodes - episode_reward: 4.302 [0.000, 12.000] - loss: 0.015 - mean_absolute_error: 2.490 - mean_q: 3.344 - mean_eps: 0.588 - ale.lives: 5.777
#
# Interval 55 (540000 steps performed)
# 10000/10000 [==============================] - 271s 27ms/step - reward: 0.0244
# 49 episodes - episode_reward: 5.061 [0.000, 11.000] - loss: 0.014 - mean_absolute_error: 2.466 - mean_q: 3.315 - mean_eps: 0.580 - ale.lives: 6.019
#
# Interval 56 (550000 steps performed)
# 10000/10000 [==============================] - 271s 27ms/step - reward: 0.0231
# 52 episodes - episode_reward: 4.365 [0.000, 11.000] - loss: 0.012 - mean_absolute_error: 2.464 - mean_q: 3.315 - mean_eps: 0.573 - ale.lives: 5.842
#
# Interval 57 (560000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0240
# 49 episodes - episode_reward: 4.918 [1.000, 14.000] - loss: 0.012 - mean_absolute_error: 2.447 - mean_q: 3.292 - mean_eps: 0.565 - ale.lives: 5.770
#
# Interval 58 (570000 steps performed)
# 10000/10000 [==============================] - 265s 26ms/step - reward: 0.0259
# 46 episodes - episode_reward: 5.609 [1.000, 11.000] - loss: 0.013 - mean_absolute_error: 2.463 - mean_q: 3.315 - mean_eps: 0.558 - ale.lives: 5.958
#
# Interval 59 (580000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0233
# 48 episodes - episode_reward: 4.958 [1.000, 10.000] - loss: 0.013 - mean_absolute_error: 2.482 - mean_q: 3.336 - mean_eps: 0.550 - ale.lives: 5.520
#
# Interval 60 (590000 steps performed)
# 10000/10000 [==============================] - 269s 27ms/step - reward: 0.0260
# 45 episodes - episode_reward: 5.756 [1.000, 13.000] - loss: 0.013 - mean_absolute_error: 2.480 - mean_q: 3.335 - mean_eps: 0.543 - ale.lives: 5.637
#
# Interval 61 (600000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0263
# 49 episodes - episode_reward: 5.327 [0.000, 20.000] - loss: 0.013 - mean_absolute_error: 2.494 - mean_q: 3.354 - mean_eps: 0.535 - ale.lives: 5.773
#
# Interval 62 (610000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0240
# 46 episodes - episode_reward: 5.217 [0.000, 13.000] - loss: 0.013 - mean_absolute_error: 2.499 - mean_q: 3.358 - mean_eps: 0.528 - ale.lives: 5.585
#
# Interval 63 (620000 steps performed)
# 10000/10000 [==============================] - 271s 27ms/step - reward: 0.0254
# 44 episodes - episode_reward: 5.659 [2.000, 13.000] - loss: 0.014 - mean_absolute_error: 2.519 - mean_q: 3.386 - mean_eps: 0.520 - ale.lives: 5.656
#
# Interval 64 (630000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0254
# 43 episodes - episode_reward: 5.837 [2.000, 13.000] - loss: 0.014 - mean_absolute_error: 2.520 - mean_q: 3.385 - mean_eps: 0.512 - ale.lives: 5.729
#
# Interval 65 (640000 steps performed)
# 10000/10000 [==============================] - 270s 27ms/step - reward: 0.0255
# 43 episodes - episode_reward: 6.140 [1.000, 15.000] - loss: 0.016 - mean_absolute_error: 2.527 - mean_q: 3.393 - mean_eps: 0.505 - ale.lives: 5.787
#
# Interval 66 (650000 steps performed)
# 10000/10000 [==============================] - 268s 27ms/step - reward: 0.02531s
# 42 episodes - episode_reward: 6.071 [1.000, 12.000] - loss: 0.015 - mean_absolute_error: 2.541 - mean_q: 3.413 - mean_eps: 0.497 - ale.lives: 5.608
#
# Interval 67 (660000 steps performed)
# 10000/10000 [==============================] - 266s 27ms/step - reward: 0.0245
# 45 episodes - episode_reward: 5.378 [0.000, 13.000] - loss: 0.014 - mean_absolute_error: 2.538 - mean_q: 3.410 - mean_eps: 0.490 - ale.lives: 5.660
#
# Interval 68 (670000 steps performed)
# 10000/10000 [==============================] - 271s 27ms/step - reward: 0.0267
# 42 episodes - episode_reward: 6.310 [0.000, 13.000] - loss: 0.014 - mean_absolute_error: 2.540 - mean_q: 3.413 - mean_eps: 0.482 - ale.lives: 5.689
#
# Interval 69 (680000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0264
# 44 episodes - episode_reward: 6.068 [0.000, 14.000] - loss: 0.014 - mean_absolute_error: 2.538 - mean_q: 3.406 - mean_eps: 0.475 - ale.lives: 5.699
#
# Interval 70 (690000 steps performed)
# 10000/10000 [==============================] - 266s 27ms/step - reward: 0.0253
# 42 episodes - episode_reward: 5.881 [0.000, 16.000] - loss: 0.014 - mean_absolute_error: 2.529 - mean_q: 3.397 - mean_eps: 0.467 - ale.lives: 5.580
#
# Interval 71 (700000 steps performed)
# 10000/10000 [==============================] - 270s 27ms/step - reward: 0.0232
# 46 episodes - episode_reward: 5.217 [0.000, 11.000] - loss: 0.015 - mean_absolute_error: 2.524 - mean_q: 3.390 - mean_eps: 0.460 - ale.lives: 5.784
#
# Interval 72 (710000 steps performed)
# 10000/10000 [==============================] - 267s 27ms/step - reward: 0.0244
# 47 episodes - episode_reward: 5.106 [0.000, 13.000] - loss: 0.013 - mean_absolute_error: 2.518 - mean_q: 3.385 - mean_eps: 0.452 - ale.lives: 5.571
#
# Interval 73 (720000 steps performed)
# 10000/10000 [==============================] - 270s 27ms/step - reward: 0.0254
# 43 episodes - episode_reward: 5.860 [0.000, 14.000] - loss: 0.014 - mean_absolute_error: 2.556 - mean_q: 3.436 - mean_eps: 0.445 - ale.lives: 5.814
#
# Interval 74 (730000 steps performed)
# 10000/10000 [==============================] - 270s 27ms/step - reward: 0.0280
# 40 episodes - episode_reward: 7.150 [1.000, 19.000] - loss: 0.015 - mean_absolute_error: 2.589 - mean_q: 3.479 - mean_eps: 0.437 - ale.lives: 5.747
#
# Interval 75 (740000 steps performed)
# 10000/10000 [==============================] - 270s 27ms/step - reward: 0.0254
# 40 episodes - episode_reward: 6.300 [1.000, 14.000] - loss: 0.016 - mean_absolute_error: 2.647 - mean_q: 3.560 - mean_eps: 0.430 - ale.lives: 5.762
#
# Interval 76 (750000 steps performed)
# 10000/10000 [==============================] - 270s 27ms/step - reward: 0.0259
# 43 episodes - episode_reward: 6.023 [1.000, 12.000] - loss: 0.015 - mean_absolute_error: 2.709 - mean_q: 3.640 - mean_eps: 0.422 - ale.lives: 5.628
#
# Interval 77 (760000 steps performed)
# 10000/10000 [==============================] - 264s 26ms/step - reward: 0.0261
# 43 episodes - episode_reward: 6.000 [0.000, 16.000] - loss: 0.015 - mean_absolute_error: 2.730 - mean_q: 3.667 - mean_eps: 0.415 - ale.lives: 5.713
#
# Interval 78 (770000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0291
# 38 episodes - episode_reward: 7.684 [1.000, 20.000] - loss: 0.014 - mean_absolute_error: 2.701 - mean_q: 3.628 - mean_eps: 0.407 - ale.lives: 5.421
#
# Interval 79 (780000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0295
# 38 episodes - episode_reward: 7.711 [0.000, 19.000] - loss: 0.014 - mean_absolute_error: 2.678 - mean_q: 3.599 - mean_eps: 0.400 - ale.lives: 5.903
#
# Interval 80 (790000 steps performed)
# 10000/10000 [==============================] - 271s 27ms/step - reward: 0.0285
# 40 episodes - episode_reward: 7.250 [1.000, 18.000] - loss: 0.014 - mean_absolute_error: 2.627 - mean_q: 3.529 - mean_eps: 0.392 - ale.lives: 5.804
#
# Interval 81 (800000 steps performed)
# 10000/10000 [==============================] - 269s 27ms/step - reward: 0.0286
# 36 episodes - episode_reward: 7.667 [1.000, 16.000] - loss: 0.014 - mean_absolute_error: 2.599 - mean_q: 3.494 - mean_eps: 0.385 - ale.lives: 5.859
#
# Interval 82 (810000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0301
# 36 episodes - episode_reward: 8.361 [2.000, 16.000] - loss: 0.013 - mean_absolute_error: 2.595 - mean_q: 3.487 - mean_eps: 0.377 - ale.lives: 5.849
#
# Interval 83 (820000 steps performed)
# 10000/10000 [==============================] - 274s 27ms/step - reward: 0.0304
# 37 episodes - episode_reward: 8.351 [3.000, 18.000] - loss: 0.013 - mean_absolute_error: 2.604 - mean_q: 3.503 - mean_eps: 0.370 - ale.lives: 5.745
#
# Interval 84 (830000 steps performed)
# 10000/10000 [==============================] - 269s 27ms/step - reward: 0.0279
# 39 episodes - episode_reward: 7.282 [4.000, 20.000] - loss: 0.014 - mean_absolute_error: 2.623 - mean_q: 3.527 - mean_eps: 0.362 - ale.lives: 5.656
#
# Interval 85 (840000 steps performed)
# 10000/10000 [==============================] - 269s 27ms/step - reward: 0.0289
# 38 episodes - episode_reward: 7.474 [1.000, 19.000] - loss: 0.014 - mean_absolute_error: 2.628 - mean_q: 3.532 - mean_eps: 0.355 - ale.lives: 5.657
#
# Interval 86 (850000 steps performed)
# 10000/10000 [==============================] - 271s 27ms/step - reward: 0.0313
# 35 episodes - episode_reward: 9.114 [4.000, 27.000] - loss: 0.013 - mean_absolute_error: 2.627 - mean_q: 3.534 - mean_eps: 0.347 - ale.lives: 5.849
#
# Interval 87 (860000 steps performed)
# 10000/10000 [==============================] - 271s 27ms/step - reward: 0.0277
# 34 episodes - episode_reward: 7.706 [4.000, 15.000] - loss: 0.013 - mean_absolute_error: 2.598 - mean_q: 3.494 - mean_eps: 0.340 - ale.lives: 5.646
#
# Interval 88 (870000 steps performed)
# 10000/10000 [==============================] - 270s 27ms/step - reward: 0.0320
# 33 episodes - episode_reward: 9.970 [3.000, 21.000] - loss: 0.013 - mean_absolute_error: 2.600 - mean_q: 3.498 - mean_eps: 0.332 - ale.lives: 5.906
#
# Interval 89 (880000 steps performed)
# 10000/10000 [==============================] - 270s 27ms/step - reward: 0.0320
# 36 episodes - episode_reward: 9.028 [1.000, 18.000] - loss: 0.013 - mean_absolute_error: 2.613 - mean_q: 3.516 - mean_eps: 0.324 - ale.lives: 5.730
#
# Interval 90 (890000 steps performed)
# 10000/10000 [==============================] - 271s 27ms/step - reward: 0.0301
# 33 episodes - episode_reward: 9.152 [3.000, 24.000] - loss: 0.013 - mean_absolute_error: 2.613 - mean_q: 3.512 - mean_eps: 0.317 - ale.lives: 5.489
#
# Interval 91 (900000 steps performed)
# 10000/10000 [==============================] - 266s 27ms/step - reward: 0.0297
# 36 episodes - episode_reward: 8.250 [2.000, 19.000] - loss: 0.013 - mean_absolute_error: 2.604 - mean_q: 3.499 - mean_eps: 0.309 - ale.lives: 6.168
#
# Interval 92 (910000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0308
# 33 episodes - episode_reward: 9.303 [2.000, 21.000] - loss: 0.014 - mean_absolute_error: 2.618 - mean_q: 3.518 - mean_eps: 0.302 - ale.lives: 5.657
#
# Interval 93 (920000 steps performed)
# 10000/10000 [==============================] - 271s 27ms/step - reward: 0.0312
# 32 episodes - episode_reward: 9.750 [1.000, 21.000] - loss: 0.015 - mean_absolute_error: 2.632 - mean_q: 3.536 - mean_eps: 0.294 - ale.lives: 5.815
#
# Interval 94 (930000 steps performed)
# 10000/10000 [==============================] - 268s 27ms/step - reward: 0.0314
# 32 episodes - episode_reward: 9.781 [3.000, 26.000] - loss: 0.014 - mean_absolute_error: 2.630 - mean_q: 3.534 - mean_eps: 0.287 - ale.lives: 5.822
#
# Interval 95 (940000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0281
# 37 episodes - episode_reward: 7.649 [1.000, 15.000] - loss: 0.014 - mean_absolute_error: 2.630 - mean_q: 3.533 - mean_eps: 0.279 - ale.lives: 5.932
#
# Interval 96 (950000 steps performed)
# 10000/10000 [==============================] - 271s 27ms/step - reward: 0.0283
# 34 episodes - episode_reward: 8.294 [1.000, 23.000] - loss: 0.014 - mean_absolute_error: 2.630 - mean_q: 3.534 - mean_eps: 0.272 - ale.lives: 5.795
#
# Interval 97 (960000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0305
# 36 episodes - episode_reward: 8.472 [1.000, 22.000] - loss: 0.014 - mean_absolute_error: 2.655 - mean_q: 3.567 - mean_eps: 0.264 - ale.lives: 5.567
#
# Interval 98 (970000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0325
# 32 episodes - episode_reward: 10.156 [3.000, 22.000] - loss: 0.013 - mean_absolute_error: 2.637 - mean_q: 3.544 - mean_eps: 0.257 - ale.lives: 5.778
#
# Interval 99 (980000 steps performed)
# 10000/10000 [==============================] - 274s 27ms/step - reward: 0.0304
# 31 episodes - episode_reward: 9.677 [3.000, 16.000] - loss: 0.013 - mean_absolute_error: 2.624 - mean_q: 3.527 - mean_eps: 0.249 - ale.lives: 5.668
#
# Interval 100 (990000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0342
# 29 episodes - episode_reward: 11.448 [4.000, 29.000] - loss: 0.012 - mean_absolute_error: 2.610 - mean_q: 3.508 - mean_eps: 0.242 - ale.lives: 5.656
#
# Interval 101 (1000000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0332
# 29 episodes - episode_reward: 11.793 [3.000, 21.000] - loss: 0.012 - mean_absolute_error: 2.575 - mean_q: 3.463 - mean_eps: 0.234 - ale.lives: 5.478
#
# Interval 102 (1010000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0323
# 31 episodes - episode_reward: 10.516 [2.000, 21.000] - loss: 0.013 - mean_absolute_error: 2.585 - mean_q: 3.473 - mean_eps: 0.227 - ale.lives: 5.533
#
# Interval 103 (1020000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0352
# 28 episodes - episode_reward: 11.929 [4.000, 31.000] - loss: 0.014 - mean_absolute_error: 2.605 - mean_q: 3.502 - mean_eps: 0.219 - ale.lives: 5.616
#
# Interval 104 (1030000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0351
# 28 episodes - episode_reward: 13.250 [3.000, 22.000] - loss: 0.013 - mean_absolute_error: 2.628 - mean_q: 3.530 - mean_eps: 0.212 - ale.lives: 5.902
#
# Interval 105 (1040000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0338
# 27 episodes - episode_reward: 12.481 [3.000, 28.000] - loss: 0.013 - mean_absolute_error: 2.639 - mean_q: 3.545 - mean_eps: 0.204 - ale.lives: 5.862
#
# Interval 106 (1050000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0339
# 28 episodes - episode_reward: 11.714 [2.000, 24.000] - loss: 0.013 - mean_absolute_error: 2.648 - mean_q: 3.557 - mean_eps: 0.197 - ale.lives: 5.888
#
# Interval 107 (1060000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0307
# 31 episodes - episode_reward: 10.226 [1.000, 22.000] - loss: 0.013 - mean_absolute_error: 2.637 - mean_q: 3.544 - mean_eps: 0.189 - ale.lives: 5.835
#
# Interval 108 (1070000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0335
# 28 episodes - episode_reward: 11.821 [4.000, 28.000] - loss: 0.013 - mean_absolute_error: 2.621 - mean_q: 3.521 - mean_eps: 0.182 - ale.lives: 5.745
#
# Interval 109 (1080000 steps performed)
# 10000/10000 [==============================] - 274s 27ms/step - reward: 0.0373
# 26 episodes - episode_reward: 13.808 [5.000, 20.000] - loss: 0.013 - mean_absolute_error: 2.619 - mean_q: 3.520 - mean_eps: 0.174 - ale.lives: 5.727
#
# Interval 110 (1090000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0375
# 27 episodes - episode_reward: 14.556 [7.000, 30.000] - loss: 0.013 - mean_absolute_error: 2.627 - mean_q: 3.532 - mean_eps: 0.167 - ale.lives: 5.849
#
# Interval 111 (1100000 steps performed)
# 10000/10000 [==============================] - 270s 27ms/step - reward: 0.0373
# 24 episodes - episode_reward: 15.208 [2.000, 37.000] - loss: 0.013 - mean_absolute_error: 2.659 - mean_q: 3.576 - mean_eps: 0.159 - ale.lives: 5.454
#
# Interval 112 (1110000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0370
# 26 episodes - episode_reward: 14.308 [6.000, 44.000] - loss: 0.013 - mean_absolute_error: 2.670 - mean_q: 3.589 - mean_eps: 0.152 - ale.lives: 5.772
#
# Interval 113 (1120000 steps performed)
# 10000/10000 [==============================] - 274s 27ms/step - reward: 0.0365
# 26 episodes - episode_reward: 14.038 [6.000, 24.000] - loss: 0.013 - mean_absolute_error: 2.694 - mean_q: 3.621 - mean_eps: 0.144 - ale.lives: 5.646
#
# Interval 114 (1130000 steps performed)
# 10000/10000 [==============================] - 275s 27ms/step - reward: 0.0338
# 27 episodes - episode_reward: 12.741 [5.000, 20.000] - loss: 0.013 - mean_absolute_error: 2.711 - mean_q: 3.643 - mean_eps: 0.136 - ale.lives: 5.537
#
# Interval 115 (1140000 steps performed)
# 10000/10000 [==============================] - 274s 27ms/step - reward: 0.0362
# 23 episodes - episode_reward: 15.130 [5.000, 29.000] - loss: 0.014 - mean_absolute_error: 2.716 - mean_q: 3.652 - mean_eps: 0.129 - ale.lives: 5.648
#
# Interval 116 (1150000 steps performed)
# 10000/10000 [==============================] - 274s 27ms/step - reward: 0.0372
# 25 episodes - episode_reward: 15.320 [5.000, 24.000] - loss: 0.014 - mean_absolute_error: 2.754 - mean_q: 3.704 - mean_eps: 0.121 - ale.lives: 5.438
#
# Interval 117 (1160000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0418
# 23 episodes - episode_reward: 18.130 [5.000, 39.000] - loss: 0.014 - mean_absolute_error: 2.763 - mean_q: 3.714 - mean_eps: 0.114 - ale.lives: 6.293
#
# Interval 118 (1170000 steps performed)
# 10000/10000 [==============================] - 269s 27ms/step - reward: 0.0398
# 25 episodes - episode_reward: 16.120 [7.000, 26.000] - loss: 0.013 - mean_absolute_error: 2.771 - mean_q: 3.723 - mean_eps: 0.106 - ale.lives: 5.354
#
# Interval 119 (1180000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0393
# 23 episodes - episode_reward: 16.739 [9.000, 32.000] - loss: 0.015 - mean_absolute_error: 2.769 - mean_q: 3.722 - mean_eps: 0.099 - ale.lives: 5.734
#
# Interval 120 (1190000 steps performed)
# 10000/10000 [==============================] - 274s 27ms/step - reward: 0.0361
# 23 episodes - episode_reward: 15.913 [8.000, 29.000] - loss: 0.015 - mean_absolute_error: 2.794 - mean_q: 3.758 - mean_eps: 0.091 - ale.lives: 5.542
#
# Interval 121 (1200000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0341
# 23 episodes - episode_reward: 14.348 [7.000, 25.000] - loss: 0.014 - mean_absolute_error: 2.785 - mean_q: 3.743 - mean_eps: 0.084 - ale.lives: 5.993
#
# Interval 122 (1210000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0365
# 24 episodes - episode_reward: 15.375 [7.000, 35.000] - loss: 0.014 - mean_absolute_error: 2.788 - mean_q: 3.746 - mean_eps: 0.076 - ale.lives: 5.797
#
# Interval 123 (1220000 steps performed)
# 10000/10000 [==============================] - 271s 27ms/step - reward: 0.0369
# 23 episodes - episode_reward: 16.435 [5.000, 31.000] - loss: 0.015 - mean_absolute_error: 2.814 - mean_q: 3.782 - mean_eps: 0.069 - ale.lives: 5.924
#
# Interval 124 (1230000 steps performed)
# 10000/10000 [==============================] - 270s 27ms/step - reward: 0.0367
# 22 episodes - episode_reward: 16.000 [6.000, 34.000] - loss: 0.014 - mean_absolute_error: 2.851 - mean_q: 3.832 - mean_eps: 0.061 - ale.lives: 5.741
#
# Interval 125 (1240000 steps performed)
# 10000/10000 [==============================] - 274s 27ms/step - reward: 0.0366
# 23 episodes - episode_reward: 16.043 [6.000, 36.000] - loss: 0.015 - mean_absolute_error: 2.861 - mean_q: 3.847 - mean_eps: 0.054 - ale.lives: 5.596
#
# Interval 126 (1250000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0352
# 20 episodes - episode_reward: 17.500 [9.000, 36.000] - loss: 0.015 - mean_absolute_error: 2.871 - mean_q: 3.858 - mean_eps: 0.050 - ale.lives: 5.920
#
# Interval 127 (1260000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0371
# 21 episodes - episode_reward: 18.429 [9.000, 28.000] - loss: 0.015 - mean_absolute_error: 2.871 - mean_q: 3.858 - mean_eps: 0.050 - ale.lives: 5.583
#
# Interval 128 (1270000 steps performed)
# 10000/10000 [==============================] - 274s 27ms/step - reward: 0.0327
# 22 episodes - episode_reward: 14.500 [6.000, 26.000] - loss: 0.015 - mean_absolute_error: 2.870 - mean_q: 3.856 - mean_eps: 0.050 - ale.lives: 5.511
#
# Interval 129 (1280000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0363
# 21 episodes - episode_reward: 16.952 [4.000, 55.000] - loss: 0.015 - mean_absolute_error: 2.862 - mean_q: 3.844 - mean_eps: 0.050 - ale.lives: 5.754
#
# Interval 130 (1290000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0364
# 22 episodes - episode_reward: 16.636 [8.000, 31.000] - loss: 0.015 - mean_absolute_error: 2.860 - mean_q: 3.842 - mean_eps: 0.050 - ale.lives: 5.845
#
# Interval 131 (1300000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0413
# 20 episodes - episode_reward: 20.800 [7.000, 33.000] - loss: 0.015 - mean_absolute_error: 2.901 - mean_q: 3.898 - mean_eps: 0.050 - ale.lives: 5.709
#
# Interval 132 (1310000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0362
# 19 episodes - episode_reward: 19.263 [11.000, 42.000] - loss: 0.015 - mean_absolute_error: 2.915 - mean_q: 3.915 - mean_eps: 0.050 - ale.lives: 5.784
#
# Interval 133 (1320000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0375
# 22 episodes - episode_reward: 17.227 [7.000, 33.000] - loss: 0.016 - mean_absolute_error: 2.921 - mean_q: 3.925 - mean_eps: 0.050 - ale.lives: 5.660
#
# Interval 134 (1330000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0359
# 22 episodes - episode_reward: 16.045 [7.000, 27.000] - loss: 0.015 - mean_absolute_error: 2.934 - mean_q: 3.941 - mean_eps: 0.050 - ale.lives: 5.591
#
# Interval 135 (1340000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0353
# 22 episodes - episode_reward: 16.045 [4.000, 38.000] - loss: 0.017 - mean_absolute_error: 2.934 - mean_q: 3.941 - mean_eps: 0.050 - ale.lives: 5.553
#
# Interval 136 (1350000 steps performed)
# 10000/10000 [==============================] - 274s 27ms/step - reward: 0.0399
# 23 episodes - episode_reward: 17.261 [5.000, 28.000] - loss: 0.016 - mean_absolute_error: 2.959 - mean_q: 3.976 - mean_eps: 0.050 - ale.lives: 5.690
#
# Interval 137 (1360000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0384
# 22 episodes - episode_reward: 17.909 [8.000, 40.000] - loss: 0.017 - mean_absolute_error: 2.984 - mean_q: 4.009 - mean_eps: 0.050 - ale.lives: 5.752
#
# Interval 138 (1370000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0391
# 21 episodes - episode_reward: 18.000 [5.000, 39.000] - loss: 0.016 - mean_absolute_error: 3.018 - mean_q: 4.057 - mean_eps: 0.050 - ale.lives: 5.484
#
# Interval 139 (1380000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0408
# 22 episodes - episode_reward: 18.818 [7.000, 34.000] - loss: 0.016 - mean_absolute_error: 3.043 - mean_q: 4.092 - mean_eps: 0.050 - ale.lives: 5.626
#
# Interval 140 (1390000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0404
# 21 episodes - episode_reward: 19.333 [8.000, 33.000] - loss: 0.017 - mean_absolute_error: 3.060 - mean_q: 4.111 - mean_eps: 0.050 - ale.lives: 5.912
#
# Interval 141 (1400000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0398
# 22 episodes - episode_reward: 18.318 [7.000, 30.000] - loss: 0.017 - mean_absolute_error: 3.068 - mean_q: 4.121 - mean_eps: 0.050 - ale.lives: 5.564
#
# Interval 142 (1410000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0386
# 21 episodes - episode_reward: 18.286 [9.000, 41.000] - loss: 0.018 - mean_absolute_error: 3.096 - mean_q: 4.157 - mean_eps: 0.050 - ale.lives: 5.852
#
# Interval 143 (1420000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0428
# 21 episodes - episode_reward: 20.238 [9.000, 45.000] - loss: 0.018 - mean_absolute_error: 3.105 - mean_q: 4.169 - mean_eps: 0.050 - ale.lives: 5.951
#
# Interval 144 (1430000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0374
# 20 episodes - episode_reward: 17.850 [4.000, 47.000] - loss: 0.018 - mean_absolute_error: 3.113 - mean_q: 4.181 - mean_eps: 0.050 - ale.lives: 5.667
#
# Interval 145 (1440000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0387
# 21 episodes - episode_reward: 18.762 [6.000, 33.000] - loss: 0.019 - mean_absolute_error: 3.144 - mean_q: 4.224 - mean_eps: 0.050 - ale.lives: 5.635
#
# Interval 146 (1450000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0412
# 21 episodes - episode_reward: 19.381 [7.000, 32.000] - loss: 0.020 - mean_absolute_error: 3.187 - mean_q: 4.279 - mean_eps: 0.050 - ale.lives: 5.966
#
# Interval 147 (1460000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0297
# 21 episodes - episode_reward: 14.905 [7.000, 28.000] - loss: 0.020 - mean_absolute_error: 3.210 - mean_q: 4.308 - mean_eps: 0.050 - ale.lives: 5.745
#
# Interval 148 (1470000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0393
# 22 episodes - episode_reward: 17.773 [6.000, 41.000] - loss: 0.019 - mean_absolute_error: 3.214 - mean_q: 4.316 - mean_eps: 0.050 - ale.lives: 5.551
#
# Interval 149 (1480000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0375
# 23 episodes - episode_reward: 16.348 [6.000, 35.000] - loss: 0.020 - mean_absolute_error: 3.211 - mean_q: 4.310 - mean_eps: 0.050 - ale.lives: 5.772
#
# Interval 150 (1490000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0373
# 21 episodes - episode_reward: 17.810 [8.000, 38.000] - loss: 0.021 - mean_absolute_error: 3.240 - mean_q: 4.350 - mean_eps: 0.050 - ale.lives: 5.387
#
# Interval 151 (1500000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0356
# 22 episodes - episode_reward: 15.864 [3.000, 26.000] - loss: 0.021 - mean_absolute_error: 3.273 - mean_q: 4.392 - mean_eps: 0.050 - ale.lives: 5.591
#
# Interval 152 (1510000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0344
# 19 episodes - episode_reward: 18.105 [7.000, 34.000] - loss: 0.021 - mean_absolute_error: 3.295 - mean_q: 4.420 - mean_eps: 0.050 - ale.lives: 5.703
#
# Interval 153 (1520000 steps performed)
# 10000/10000 [==============================] - 275s 28ms/step - reward: 0.0337
# 22 episodes - episode_reward: 15.545 [9.000, 31.000] - loss: 0.022 - mean_absolute_error: 3.277 - mean_q: 4.396 - mean_eps: 0.050 - ale.lives: 5.668
#
# Interval 154 (1530000 steps performed)
# 10000/10000 [==============================] - 275s 28ms/step - reward: 0.0344
# 25 episodes - episode_reward: 13.520 [3.000, 26.000] - loss: 0.021 - mean_absolute_error: 3.277 - mean_q: 4.397 - mean_eps: 0.050 - ale.lives: 5.731
#
# Interval 155 (1540000 steps performed)
# 10000/10000 [==============================] - 275s 27ms/step - reward: 0.0360
# 23 episodes - episode_reward: 15.913 [7.000, 29.000] - loss: 0.022 - mean_absolute_error: 3.290 - mean_q: 4.415 - mean_eps: 0.050 - ale.lives: 5.533
#
# Interval 156 (1550000 steps performed)
# 10000/10000 [==============================] - 268s 27ms/step - reward: 0.0342
# 20 episodes - episode_reward: 16.300 [7.000, 29.000] - loss: 0.021 - mean_absolute_error: 3.288 - mean_q: 4.414 - mean_eps: 0.050 - ale.lives: 5.650
#
# Interval 157 (1560000 steps performed)
# 10000/10000 [==============================] - 273s 27ms/step - reward: 0.0352
# 24 episodes - episode_reward: 15.500 [7.000, 38.000] - loss: 0.021 - mean_absolute_error: 3.295 - mean_q: 4.424 - mean_eps: 0.050 - ale.lives: 5.821
#
# Interval 158 (1570000 steps performed)
# 10000/10000 [==============================] - 270s 27ms/step - reward: 0.0346
# 22 episodes - episode_reward: 15.409 [5.000, 27.000] - loss: 0.022 - mean_absolute_error: 3.316 - mean_q: 4.451 - mean_eps: 0.050 - ale.lives: 5.713
#
# Interval 159 (1580000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0354
# 22 episodes - episode_reward: 16.000 [5.000, 29.000] - loss: 0.022 - mean_absolute_error: 3.333 - mean_q: 4.473 - mean_eps: 0.050 - ale.lives: 5.923
#
# Interval 160 (1590000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0323
# 25 episodes - episode_reward: 13.160 [4.000, 20.000] - loss: 0.022 - mean_absolute_error: 3.351 - mean_q: 4.499 - mean_eps: 0.050 - ale.lives: 5.901
#
# Interval 161 (1600000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0360
# 21 episodes - episode_reward: 17.286 [4.000, 39.000] - loss: 0.022 - mean_absolute_error: 3.373 - mean_q: 4.528 - mean_eps: 0.050 - ale.lives: 5.648
#
# Interval 162 (1610000 steps performed)
# 10000/10000 [==============================] - 271s 27ms/step - reward: 0.0375
# 22 episodes - episode_reward: 16.727 [5.000, 33.000] - loss: 0.024 - mean_absolute_error: 3.374 - mean_q: 4.530 - mean_eps: 0.050 - ale.lives: 5.735
#
# Interval 163 (1620000 steps performed)
# 10000/10000 [==============================] - 274s 27ms/step - reward: 0.0368
# 22 episodes - episode_reward: 17.045 [4.000, 37.000] - loss: 0.024 - mean_absolute_error: 3.399 - mean_q: 4.561 - mean_eps: 0.050 - ale.lives: 5.627
#
# Interval 164 (1630000 steps performed)
# 10000/10000 [==============================] - 272s 27ms/step - reward: 0.0383
# 22 episodes - episode_reward: 17.091 [5.000, 35.000] - loss: 0.026 - mean_absolute_error: 3.410 - mean_q: 4.575 - mean_eps: 0.050 - ale.lives: 5.925
#
# Interval 165 (1640000 steps performed)
# 10000/10000 [==============================] - 276s 28ms/step - reward: 0.0347
# 25 episodes - episode_reward: 13.720 [4.000, 25.000] - loss: 0.025 - mean_absolute_error: 3.403 - mean_q: 4.567 - mean_eps: 0.050 - ale.lives: 5.654
#
# Interval 166 (1650000 steps performed)
# 10000/10000 [==============================] - 287s 29ms/step - reward: 0.0345
# 25 episodes - episode_reward: 13.800 [2.000, 28.000] - loss: 0.025 - mean_absolute_error: 3.396 - mean_q: 4.556 - mean_eps: 0.050 - ale.lives: 5.654
#
# Interval 167 (1660000 steps performed)
# 10000/10000 [==============================] - 289s 29ms/step - reward: 0.0347
# 25 episodes - episode_reward: 14.360 [5.000, 27.000] - loss: 0.026 - mean_absolute_error: 3.418 - mean_q: 4.584 - mean_eps: 0.050 - ale.lives: 6.066
#
# Interval 168 (1670000 steps performed)
# 10000/10000 [==============================] - 288s 29ms/step - reward: 0.0357
# 23 episodes - episode_reward: 15.435 [5.000, 34.000] - loss: 0.030 - mean_absolute_error: 3.450 - mean_q: 4.629 - mean_eps: 0.050 - ale.lives: 5.848
#
# Interval 169 (1680000 steps performed)
# 10000/10000 [==============================] - 296s 30ms/step - reward: 0.0377
# 23 episodes - episode_reward: 16.130 [4.000, 31.000] - loss: 0.028 - mean_absolute_error: 3.464 - mean_q: 4.649 - mean_eps: 0.050 - ale.lives: 5.663
#
# Interval 170 (1690000 steps performed)
# 10000/10000 [==============================] - 289s 29ms/step - reward: 0.0343
# 26 episodes - episode_reward: 13.500 [4.000, 28.000] - loss: 0.033 - mean_absolute_error: 3.555 - mean_q: 4.769 - mean_eps: 0.050 - ale.lives: 5.644
#
# Interval 171 (1700000 steps performed)
# 10000/10000 [==============================] - 290s 29ms/step - reward: 0.0315
# 25 episodes - episode_reward: 12.560 [4.000, 23.000] - loss: 0.037 - mean_absolute_error: 3.597 - mean_q: 4.823 - mean_eps: 0.050 - ale.lives: 5.584
#
# Interval 172 (1710000 steps performed)
# 10000/10000 [==============================] - 293s 29ms/step - reward: 0.0338
# 25 episodes - episode_reward: 13.360 [4.000, 27.000] - loss: 0.037 - mean_absolute_error: 3.618 - mean_q: 4.852 - mean_eps: 0.050 - ale.lives: 5.779
#
# Interval 173 (1720000 steps performed)
# 10000/10000 [==============================] - 296s 30ms/step - reward: 0.0287
# 23 episodes - episode_reward: 12.174 [3.000, 23.000] - loss: 0.037 - mean_absolute_error: 3.674 - mean_q: 4.927 - mean_eps: 0.050 - ale.lives: 5.553
#
# Interval 174 (1730000 steps performed)
# 10000/10000 [==============================] - 296s 30ms/step - reward: 0.0320
# 24 episodes - episode_reward: 13.500 [4.000, 31.000] - loss: 0.034 - mean_absolute_error: 3.613 - mean_q: 4.843 - mean_eps: 0.050 - ale.lives: 5.785
#
# Interval 175 (1740000 steps performed)
# 10000/10000 [==============================] - 295s 29ms/step - reward: 0.0359
# done, took 46901.213 seconds

# %%
for _ in range(10):
    orig_environment = gym.make('Breakout-v0')
    environment = wrappers.Monitor(orig_environment, "gym-videos/", force=True)

    # Lets visualize a single playthrough.
    state = environment.reset()
    dqn.test(environment, nb_episodes=1, visualize=True, nb_max_start_steps=30, action_repetition=2)

    environment.close()
    orig_environment.close()

    display.display(imbed_round_video(environment))
# Out:
# Testing for 1 episodes ...
# Episode 1: reward: 14.000, steps: 414
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
# Testing for 1 episodes ...
# Episode 1: reward: 20.000, steps: 4997
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
# Testing for 1 episodes ...
# Episode 1: reward: 5.000, steps: 5000
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
# Testing for 1 episodes ...
# Episode 1: reward: 10.000, steps: 4994
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
# Testing for 1 episodes ...
# Episode 1: reward: 36.000, steps: 693
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
# Testing for 1 episodes ...
# Episode 1: reward: 15.000, steps: 448
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
# Testing for 1 episodes ...
# Episode 1: reward: 24.000, steps: 365
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
# Testing for 1 episodes ...
# Episode 1: reward: 12.000, steps: 390
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
# Testing for 1 episodes ...
# Episode 1: reward: 21.000, steps: 507
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
# Testing for 1 episodes ...
# Episode 1: reward: 14.000, steps: 307
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>

# %%
# You'll notice some very silly behavior, sometimes if the ball falls
# off screen and then the agent just sits there — this is because it
# has not learned that it has to take the "Fire" action to get another
# ball, for example. 

# You'll also notice that for having played millions of steps and thousands
# of rounds of Breakout.... even the best episodes are only okay. This 
# implementation has several state-of-the-art best practices, but learning
# from raw pixel data is still hard. 

# Tactics like reward augmentation can still help, and explicitly extracting
# useful state information can help further.
